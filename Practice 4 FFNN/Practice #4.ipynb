# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from utils_3 import mnist, plot_graphs

# %matplotlib inline

# In[20]:


train_loader, valid_loader, test_loader = mnist(valid=10000)


# In[88]:


class Net(nn.Module):
    def __init__(self, lr=1e-4, l2=0.):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 1000)
        nn.init.xavier_uniform_(self.fc1.weight)
        self.fc2 = nn.Linear(1000, 1000)  #
        nn.init.xavier_uniform_(self.fc2.weight)
        self.fc3 = nn.Linear(1000, 1000)  # nn.Linear(128, 256)
        nn.init.xavier_uniform_(self.fc3.weight)
        self.fc4 = nn.Linear(1000, 10)
        self.bn = nn.BatchNorm1d(1000)
        self.optim = optim.Adam(self.parameters(), lr=lr, weight_decay=l2)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = F.relu(self.fc1(x))
        x = self.bn(x)
        x = F.relu(self.fc2(x))
        x = F.dropout(x, 0.5)
        x = F.relu(self.fc3(x))
        x = F.dropout(x, 0.5)
        x = self.fc4(x)
        x = F.log_softmax(x, dim=1)
        return x

    def loss(self, output, target, **kwargs):
        self._loss = F.nll_loss(output, target, **kwargs)
        self._correct = output.data.max(1, keepdim=True)[1]
        self._correct = self._correct.eq(target.data.view_as(self._correct)).to(torch.float).cpu().mean()
        return self._loss


# In[89]:


models = {'default': Net()}
train_log = {k: [] for k in models}
valid_log = {k: [] for k in models}
test_log = {k: [] for k in models}


# In[7]:


def train(epoch, models, log=None):
    train_size = len(train_loader.sampler)
    for batch_idx, (data, target) in enumerate(train_loader):
        for model in models.values():
            model.optim.zero_grad()
            output = model(data)
            loss = model.loss(output, target)
            loss.backward()
            model.optim.step()

        if batch_idx % 200 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
            losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
            print(line + losses)

    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
        losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
        if log is not None:
            for k in models:
                log[k].append((models[k]._loss, models[k]._correct))
        print(line + losses)


# In[8]:


def test(models, loader, log=None):
    test_size = len(loader.sampler)
    avg_lambda = lambda l: 'Loss: {:.4f}'.format(l)
    acc_lambda = lambda c, p: 'Accuracy: {}/{} ({:.0f}%)'.format(c, test_size, p)
    line = lambda i, l, c, p: '{}: '.format(i) + avg_lambda(l) + '\t' + acc_lambda(c, p)

    test_loss = {k: 0. for k in models}
    correct = {k: 0. for k in models}
    with torch.no_grad():
        for data, target in loader:
            output = {k: m(data) for k, m in models.items()}
            for k, m in models.items():
                test_loss[k] += m.loss(output[k], target, size_average=False).item()  # sum up batch loss
                pred = output[k].data.max(1, keepdim=True)[1]  # get the index of the max log-probability
                correct[k] += pred.eq(target.data.view_as(pred)).cpu().sum()

    for k in models:
        test_loss[k] /= test_size
    correct_pct = {k: c.to(torch.float) / test_size for k, c in correct.items()}
    lines = '\n'.join([line(k, test_loss[k], correct[k], 100 * correct_pct[k]) for k in models]) + '\n'
    report = 'Test set:\n' + lines
    if log is not None:
        for k in models:
            log[k].append((test_loss[k], correct_pct[k]))
    print(report)


# In[9]:


if __name__ == '__main__':
    for epoch in range(1, 101):
        for model in models.values():
            model.train()
        train(epoch, models, train_log)
        for model in models.values():
            model.eval()
        test(models, valid_loader, valid_log)
        test(models, test_loader, test_log)
    plot_graphs(test_log, 'loss')
    plot_graphs(test_log, 'accuracy')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Losses default: 2.313228
# Train Epoch: 1 [10000/50000 (20%)]	Losses default: 0.537088
# Train Epoch: 1 [20000/50000 (40%)]	Losses default: 0.455736
# Train Epoch: 1 [30000/50000 (60%)]	Losses default: 0.417310
# Train Epoch: 1 [40000/50000 (80%)]	Losses default: 0.293845
# Train Epoch: 1 [50000/50000 (100%)]	Losses default: 0.449122
# Test set:
# default: Loss: 0.3567	Accuracy: 8690/10000 (87%)
#
# Test set:
# default: Loss: 0.3717	Accuracy: 8667/10000 (87%)
#
# Train Epoch: 2 [0/50000 (0%)]	Losses default: 0.269474
# Train Epoch: 2 [10000/50000 (20%)]	Losses default: 0.349202
# Train Epoch: 2 [20000/50000 (40%)]	Losses default: 0.475077
# Train Epoch: 2 [30000/50000 (60%)]	Losses default: 0.307998
# Train Epoch: 2 [40000/50000 (80%)]	Losses default: 0.388467
# Train Epoch: 2 [50000/50000 (100%)]	Losses default: 0.314963
# Test set:
# default: Loss: 0.3459	Accuracy: 8708/10000 (87%)
#
# Test set:
# default: Loss: 0.3631	Accuracy: 8660/10000 (87%)
#
# Train Epoch: 3 [0/50000 (0%)]	Losses default: 0.245509
# Train Epoch: 3 [10000/50000 (20%)]	Losses default: 0.116225
# Train Epoch: 3 [20000/50000 (40%)]	Losses default: 0.482032
# Train Epoch: 3 [30000/50000 (60%)]	Losses default: 0.430921
# Train Epoch: 3 [40000/50000 (80%)]	Losses default: 0.250899
# Train Epoch: 3 [50000/50000 (100%)]	Losses default: 0.319847
# Test set:
# default: Loss: 0.3203	Accuracy: 8844/10000 (88%)
#
# Test set:
# default: Loss: 0.3419	Accuracy: 8796/10000 (88%)
#
# Train Epoch: 4 [0/50000 (0%)]	Losses default: 0.225018
# Train Epoch: 4 [10000/50000 (20%)]	Losses default: 0.262337
# Train Epoch: 4 [20000/50000 (40%)]	Losses default: 0.343017
# Train Epoch: 4 [30000/50000 (60%)]	Losses default: 0.379312
# Train Epoch: 4 [40000/50000 (80%)]	Losses default: 0.134830
# Train Epoch: 4 [50000/50000 (100%)]	Losses default: 0.119737
# Test set:
# default: Loss: 0.3115	Accuracy: 8870/10000 (89%)
#
# Test set:
# default: Loss: 0.3300	Accuracy: 8834/10000 (88%)
#
# Train Epoch: 5 [0/50000 (0%)]	Losses default: 0.140587
# Train Epoch: 5 [10000/50000 (20%)]	Losses default: 0.176804
# Train Epoch: 5 [20000/50000 (40%)]	Losses default: 0.203178
# Train Epoch: 5 [30000/50000 (60%)]	Losses default: 0.146693
# Train Epoch: 5 [40000/50000 (80%)]	Losses default: 0.293073
# Train Epoch: 5 [50000/50000 (100%)]	Losses default: 0.276306
# Test set:
# default: Loss: 0.3448	Accuracy: 8746/10000 (87%)
#
# Test set:
# default: Loss: 0.3713	Accuracy: 8690/10000 (87%)
#
# Train Epoch: 6 [0/50000 (0%)]	Losses default: 0.246428
# Train Epoch: 6 [10000/50000 (20%)]	Losses default: 0.248107
# Train Epoch: 6 [20000/50000 (40%)]	Losses default: 0.243169
# Train Epoch: 6 [30000/50000 (60%)]	Losses default: 0.219537
# Train Epoch: 6 [40000/50000 (80%)]	Losses default: 0.339785
# Train Epoch: 6 [50000/50000 (100%)]	Losses default: 0.133168
# Test set:
# default: Loss: 0.3216	Accuracy: 8864/10000 (89%)
#
# Test set:
# default: Loss: 0.3416	Accuracy: 8835/10000 (88%)
#
# Train Epoch: 7 [0/50000 (0%)]	Losses default: 0.206649
# Train Epoch: 7 [10000/50000 (20%)]	Losses default: 0.191234
# Train Epoch: 7 [20000/50000 (40%)]	Losses default: 0.168403
# Train Epoch: 7 [30000/50000 (60%)]	Losses default: 0.119989
# Train Epoch: 7 [40000/50000 (80%)]	Losses default: 0.272857
# Train Epoch: 7 [50000/50000 (100%)]	Losses default: 0.321297
# Test set:
# default: Loss: 0.3210	Accuracy: 8879/10000 (89%)
#
# Test set:
# default: Loss: 0.3444	Accuracy: 8837/10000 (88%)
#
# Train Epoch: 8 [0/50000 (0%)]	Losses default: 0.193192
# Train Epoch: 8 [10000/50000 (20%)]	Losses default: 0.102399
# Train Epoch: 8 [20000/50000 (40%)]	Losses default: 0.365102
# Train Epoch: 8 [30000/50000 (60%)]	Losses default: 0.228102
# Train Epoch: 8 [40000/50000 (80%)]	Losses default: 0.269439
# Train Epoch: 8 [50000/50000 (100%)]	Losses default: 0.200826
# Test set:
# default: Loss: 0.3430	Accuracy: 8848/10000 (88%)
#
# Test set:
# default: Loss: 0.3571	Accuracy: 8800/10000 (88%)
#
# Train Epoch: 9 [0/50000 (0%)]	Losses default: 0.079837
# Train Epoch: 9 [10000/50000 (20%)]	Losses default: 0.179204
# Train Epoch: 9 [20000/50000 (40%)]	Losses default: 0.140551
# Train Epoch: 9 [30000/50000 (60%)]	Losses default: 0.170852
# Train Epoch: 9 [40000/50000 (80%)]	Losses default: 0.085935
# Train Epoch: 9 [50000/50000 (100%)]	Losses default: 0.170372
# Test set:
# default: Loss: 0.3306	Accuracy: 8920/10000 (89%)
#
# Test set:
# default: Loss: 0.3386	Accuracy: 8894/10000 (89%)
#
# Train Epoch: 10 [0/50000 (0%)]	Losses default: 0.151322
# Train Epoch: 10 [10000/50000 (20%)]	Losses default: 0.072666
# Train Epoch: 10 [20000/50000 (40%)]	Losses default: 0.266396
# Train Epoch: 10 [30000/50000 (60%)]	Losses default: 0.164656
# Train Epoch: 10 [40000/50000 (80%)]	Losses default: 0.236851
# Train Epoch: 10 [50000/50000 (100%)]	Losses default: 0.077493
# Test set:
# default: Loss: 0.3568	Accuracy: 8821/10000 (88%)
#
# Test set:
# default: Loss: 0.3815	Accuracy: 8816/10000 (88%)
#
# Train Epoch: 11 [0/50000 (0%)]	Losses default: 0.134094
# Train Epoch: 11 [10000/50000 (20%)]	Losses default: 0.137905
# Train Epoch: 11 [20000/50000 (40%)]	Losses default: 0.193536
# Train Epoch: 11 [30000/50000 (60%)]	Losses default: 0.132923
# Train Epoch: 11 [40000/50000 (80%)]	Losses default: 0.215044
# Train Epoch: 11 [50000/50000 (100%)]	Losses default: 0.323766
# Test set:
# default: Loss: 0.3408	Accuracy: 8877/10000 (89%)
#
# Test set:
# default: Loss: 0.3617	Accuracy: 8821/10000 (88%)
#
# Train Epoch: 12 [0/50000 (0%)]	Losses default: 0.231267
# Train Epoch: 12 [10000/50000 (20%)]	Losses default: 0.255070
# Train Epoch: 12 [20000/50000 (40%)]	Losses default: 0.186003
# Train Epoch: 12 [30000/50000 (60%)]	Losses default: 0.131601
# Train Epoch: 12 [40000/50000 (80%)]	Losses default: 0.241348
# Train Epoch: 12 [50000/50000 (100%)]	Losses default: 0.187948
# Test set:
# default: Loss: 0.3507	Accuracy: 8909/10000 (89%)
#
# Test set:
# default: Loss: 0.3600	Accuracy: 8909/10000 (89%)
#
# Train Epoch: 13 [0/50000 (0%)]	Losses default: 0.090618
# Train Epoch: 13 [10000/50000 (20%)]	Losses default: 0.075625
# Train Epoch: 13 [20000/50000 (40%)]	Losses default: 0.188327
# Train Epoch: 13 [30000/50000 (60%)]	Losses default: 0.162433
# Train Epoch: 13 [40000/50000 (80%)]	Losses default: 0.097579
# Train Epoch: 13 [50000/50000 (100%)]	Losses default: 0.223286
# Test set:
# default: Loss: 0.3660	Accuracy: 8821/10000 (88%)
#
# Test set:
# default: Loss: 0.3859	Accuracy: 8805/10000 (88%)
#
# Train Epoch: 14 [0/50000 (0%)]	Losses default: 0.072145
# Train Epoch: 14 [10000/50000 (20%)]	Losses default: 0.061960
# Train Epoch: 14 [20000/50000 (40%)]	Losses default: 0.108971
# Train Epoch: 14 [30000/50000 (60%)]	Losses default: 0.219654
# Train Epoch: 14 [40000/50000 (80%)]	Losses default: 0.094069
# Train Epoch: 14 [50000/50000 (100%)]	Losses default: 0.172974
# Test set:
# default: Loss: 0.3841	Accuracy: 8886/10000 (89%)
#
# Test set:
# default: Loss: 0.4104	Accuracy: 8830/10000 (88%)
#
# Train Epoch: 15 [0/50000 (0%)]	Losses default: 0.053532
# Train Epoch: 15 [10000/50000 (20%)]	Losses default: 0.179289
# Train Epoch: 15 [20000/50000 (40%)]	Losses default: 0.044000
# Train Epoch: 15 [30000/50000 (60%)]	Losses default: 0.101946
# Train Epoch: 15 [40000/50000 (80%)]	Losses default: 0.036774
# Train Epoch: 15 [50000/50000 (100%)]	Losses default: 0.120301
# Test set:
# default: Loss: 0.3957	Accuracy: 8865/10000 (89%)
#
# Test set:
# default: Loss: 0.4188	Accuracy: 8852/10000 (89%)
#
# Train Epoch: 16 [0/50000 (0%)]	Losses default: 0.135931
# Train Epoch: 16 [10000/50000 (20%)]	Losses default: 0.027138
# Train Epoch: 16 [20000/50000 (40%)]	Losses default: 0.092786
# Train Epoch: 16 [30000/50000 (60%)]	Losses default: 0.164469
# Train Epoch: 16 [40000/50000 (80%)]	Losses default: 0.086379
# Train Epoch: 16 [50000/50000 (100%)]	Losses default: 0.142183
# Test set:
# default: Loss: 0.3804	Accuracy: 8908/10000 (89%)
#
# Test set:
# default: Loss: 0.4244	Accuracy: 8818/10000 (88%)
#
# Train Epoch: 17 [0/50000 (0%)]	Losses default: 0.078487
# Train Epoch: 17 [10000/50000 (20%)]	Losses default: 0.103893
# Train Epoch: 17 [20000/50000 (40%)]	Losses default: 0.089104
# Train Epoch: 17 [30000/50000 (60%)]	Losses default: 0.171745
# Train Epoch: 17 [40000/50000 (80%)]	Losses default: 0.189239
# Train Epoch: 17 [50000/50000 (100%)]	Losses default: 0.112975
# Test set:
# default: Loss: 0.3685	Accuracy: 8915/10000 (89%)
#
# Test set:
# default: Loss: 0.4203	Accuracy: 8852/10000 (89%)
#
# Train Epoch: 18 [0/50000 (0%)]	Losses default: 0.068626
# Train Epoch: 18 [10000/50000 (20%)]	Losses default: 0.120901
# Train Epoch: 18 [20000/50000 (40%)]	Losses default: 0.112664
# Train Epoch: 18 [30000/50000 (60%)]	Losses default: 0.059321
# Train Epoch: 18 [40000/50000 (80%)]	Losses default: 0.152490
# Train Epoch: 18 [50000/50000 (100%)]	Losses default: 0.241419
# Test set:
# default: Loss: 0.4385	Accuracy: 8846/10000 (88%)
#
# Test set:
# default: Loss: 0.4779	Accuracy: 8757/10000 (88%)
#
# Train Epoch: 19 [0/50000 (0%)]	Losses default: 0.146085
# Train Epoch: 19 [10000/50000 (20%)]	Losses default: 0.149427
# Train Epoch: 19 [20000/50000 (40%)]	Losses default: 0.094853
# Train Epoch: 19 [30000/50000 (60%)]	Losses default: 0.111379
# Train Epoch: 19 [40000/50000 (80%)]	Losses default: 0.040795
# Train Epoch: 19 [50000/50000 (100%)]	Losses default: 0.127800
# Test set:
# default: Loss: 0.4030	Accuracy: 8890/10000 (89%)
#
# Test set:
# default: Loss: 0.4364	Accuracy: 8848/10000 (88%)
#
# Train Epoch: 20 [0/50000 (0%)]	Losses default: 0.028671
# Train Epoch: 20 [10000/50000 (20%)]	Losses default: 0.104969
# Train Epoch: 20 [20000/50000 (40%)]	Losses default: 0.037043
# Train Epoch: 20 [30000/50000 (60%)]	Losses default: 0.100609
# Train Epoch: 20 [40000/50000 (80%)]	Losses default: 0.054477
# Train Epoch: 20 [50000/50000 (100%)]	Losses default: 0.131440
# Test set:
# default: Loss: 0.4320	Accuracy: 8885/10000 (89%)
#
# Test set:
# default: Loss: 0.4539	Accuracy: 8873/10000 (89%)
#
# Train Epoch: 21 [0/50000 (0%)]	Losses default: 0.045000
# Train Epoch: 21 [10000/50000 (20%)]	Losses default: 0.106579
# Train Epoch: 21 [20000/50000 (40%)]	Losses default: 0.058930
# Train Epoch: 21 [30000/50000 (60%)]	Losses default: 0.195385
# Train Epoch: 21 [40000/50000 (80%)]	Losses default: 0.016643
# Train Epoch: 21 [50000/50000 (100%)]	Losses default: 0.067471
# Test set:
# default: Loss: 0.4210	Accuracy: 8887/10000 (89%)
#
# Test set:
# default: Loss: 0.4468	Accuracy: 8857/10000 (89%)
#
# Train Epoch: 22 [0/50000 (0%)]	Losses default: 0.131682
# Train Epoch: 22 [10000/50000 (20%)]	Losses default: 0.031396
# Train Epoch: 22 [20000/50000 (40%)]	Losses default: 0.147280
# Train Epoch: 22 [30000/50000 (60%)]	Losses default: 0.114152
# Train Epoch: 22 [40000/50000 (80%)]	Losses default: 0.119663
# Train Epoch: 22 [50000/50000 (100%)]	Losses default: 0.164413
# Test set:
# default: Loss: 0.4452	Accuracy: 8882/10000 (89%)
#
# Test set:
# default: Loss: 0.4673	Accuracy: 8882/10000 (89%)
#
# Train Epoch: 23 [0/50000 (0%)]	Losses default: 0.159073
# Train Epoch: 23 [10000/50000 (20%)]	Losses default: 0.094215
# Train Epoch: 23 [20000/50000 (40%)]	Losses default: 0.124601
# Train Epoch: 23 [30000/50000 (60%)]	Losses default: 0.113153
# Train Epoch: 23 [40000/50000 (80%)]	Losses default: 0.031351
# Train Epoch: 23 [50000/50000 (100%)]	Losses default: 0.038270
# Test set:
# default: Loss: 0.4236	Accuracy: 8905/10000 (89%)
#
# Test set:
# default: Loss: 0.4451	Accuracy: 8861/10000 (89%)
#
# Train Epoch: 24 [0/50000 (0%)]	Losses default: 0.040891
# Train Epoch: 24 [10000/50000 (20%)]	Losses default: 0.011627
# Train Epoch: 24 [20000/50000 (40%)]	Losses default: 0.097838
# Train Epoch: 24 [30000/50000 (60%)]	Losses default: 0.077845
# Train Epoch: 24 [40000/50000 (80%)]	Losses default: 0.120905
# Train Epoch: 24 [50000/50000 (100%)]	Losses default: 0.118000
# Test set:
# default: Loss: 0.4393	Accuracy: 8916/10000 (89%)
#
# Test set:
# default: Loss: 0.4644	Accuracy: 8890/10000 (89%)
#
# Train Epoch: 25 [0/50000 (0%)]	Losses default: 0.161747
# Train Epoch: 25 [10000/50000 (20%)]	Losses default: 0.042924
# Train Epoch: 25 [20000/50000 (40%)]	Losses default: 0.054267
# Train Epoch: 25 [30000/50000 (60%)]	Losses default: 0.081468
# Train Epoch: 25 [40000/50000 (80%)]	Losses default: 0.016697
# Train Epoch: 25 [50000/50000 (100%)]	Losses default: 0.040540
# Test set:
# default: Loss: 0.4386	Accuracy: 8892/10000 (89%)
#
# Test set:
# default: Loss: 0.4706	Accuracy: 8886/10000 (89%)
#
# Train Epoch: 26 [0/50000 (0%)]	Losses default: 0.073236
# Train Epoch: 26 [10000/50000 (20%)]	Losses default: 0.026675
# Train Epoch: 26 [20000/50000 (40%)]	Losses default: 0.012749
# Train Epoch: 26 [30000/50000 (60%)]	Losses default: 0.059394
# Train Epoch: 26 [40000/50000 (80%)]	Losses default: 0.008751
# Train Epoch: 26 [50000/50000 (100%)]	Losses default: 0.044402
# Test set:
# default: Loss: 0.4419	Accuracy: 8878/10000 (89%)
#
# Test set:
# default: Loss: 0.4792	Accuracy: 8883/10000 (89%)
#
# Train Epoch: 27 [0/50000 (0%)]	Losses default: 0.060785
# Train Epoch: 27 [10000/50000 (20%)]	Losses default: 0.040611
# Train Epoch: 27 [20000/50000 (40%)]	Losses default: 0.104805
# Train Epoch: 27 [30000/50000 (60%)]	Losses default: 0.122799
# Train Epoch: 27 [40000/50000 (80%)]	Losses default: 0.077104
# Train Epoch: 27 [50000/50000 (100%)]	Losses default: 0.052032
# Test set:
# default: Loss: 0.4572	Accuracy: 8893/10000 (89%)
#
# Test set:
# default: Loss: 0.4888	Accuracy: 8885/10000 (89%)
#
# Train Epoch: 28 [0/50000 (0%)]	Losses default: 0.036554
# Train Epoch: 28 [10000/50000 (20%)]	Losses default: 0.050152
# Train Epoch: 28 [20000/50000 (40%)]	Losses default: 0.052645
# Train Epoch: 28 [30000/50000 (60%)]	Losses default: 0.073899
# Train Epoch: 28 [40000/50000 (80%)]	Losses default: 0.049725
# Train Epoch: 28 [50000/50000 (100%)]	Losses default: 0.010016
# Test set:
# default: Loss: 0.4957	Accuracy: 8882/10000 (89%)
#
# Test set:
# default: Loss: 0.5525	Accuracy: 8814/10000 (88%)
#
# Train Epoch: 29 [0/50000 (0%)]	Losses default: 0.085973
# Train Epoch: 29 [10000/50000 (20%)]	Losses default: 0.144397
# Train Epoch: 29 [20000/50000 (40%)]	Losses default: 0.046681
# Train Epoch: 29 [30000/50000 (60%)]	Losses default: 0.030004
# Train Epoch: 29 [40000/50000 (80%)]	Losses default: 0.128050
# Train Epoch: 29 [50000/50000 (100%)]	Losses default: 0.031869
# Test set:
# default: Loss: 0.4728	Accuracy: 8888/10000 (89%)
#
# Test set:
# default: Loss: 0.4910	Accuracy: 8907/10000 (89%)
#
# Train Epoch: 30 [0/50000 (0%)]	Losses default: 0.016343
# Train Epoch: 30 [10000/50000 (20%)]	Losses default: 0.067067
# Train Epoch: 30 [20000/50000 (40%)]	Losses default: 0.086673
# Train Epoch: 30 [30000/50000 (60%)]	Losses default: 0.199180
# Train Epoch: 30 [40000/50000 (80%)]	Losses default: 0.021773
# Train Epoch: 30 [50000/50000 (100%)]	Losses default: 0.062810
# Test set:
# default: Loss: 0.5075	Accuracy: 8939/10000 (89%)
#
# Test set:
# default: Loss: 0.5422	Accuracy: 8913/10000 (89%)
#
# Train Epoch: 31 [0/50000 (0%)]	Losses default: 0.217178
# Train Epoch: 31 [10000/50000 (20%)]	Losses default: 0.058612
# Train Epoch: 31 [20000/50000 (40%)]	Losses default: 0.003259
# Train Epoch: 31 [30000/50000 (60%)]	Losses default: 0.018383
# Train Epoch: 31 [40000/50000 (80%)]	Losses default: 0.022577
# Train Epoch: 31 [50000/50000 (100%)]	Losses default: 0.051267
# Test set:
# default: Loss: 0.4747	Accuracy: 8917/10000 (89%)
#
# Test set:
# default: Loss: 0.5345	Accuracy: 8835/10000 (88%)
#
# Train Epoch: 32 [0/50000 (0%)]	Losses default: 0.029210
# Train Epoch: 32 [10000/50000 (20%)]	Losses default: 0.021410
# Train Epoch: 32 [20000/50000 (40%)]	Losses default: 0.050715
# Train Epoch: 32 [30000/50000 (60%)]	Losses default: 0.108122
# Train Epoch: 32 [40000/50000 (80%)]	Losses default: 0.004990
# Train Epoch: 32 [50000/50000 (100%)]	Losses default: 0.101221
# Test set:
# default: Loss: 0.4767	Accuracy: 8899/10000 (89%)
#
# Test set:
# default: Loss: 0.5498	Accuracy: 8849/10000 (88%)
#
# Train Epoch: 33 [0/50000 (0%)]	Losses default: 0.043094
# Train Epoch: 33 [10000/50000 (20%)]	Losses default: 0.052998
# Train Epoch: 33 [20000/50000 (40%)]	Losses default: 0.099644
# Train Epoch: 33 [30000/50000 (60%)]	Losses default: 0.009663
# Train Epoch: 33 [40000/50000 (80%)]	Losses default: 0.045867
# Train Epoch: 33 [50000/50000 (100%)]	Losses default: 0.038666
# Test set:
# default: Loss: 0.5118	Accuracy: 8923/10000 (89%)
#
# Test set:
# default: Loss: 0.5430	Accuracy: 8866/10000 (89%)
#
# Train Epoch: 34 [0/50000 (0%)]	Losses default: 0.029844
# Train Epoch: 34 [10000/50000 (20%)]	Losses default: 0.009078
# Train Epoch: 34 [20000/50000 (40%)]	Losses default: 0.034865
# Train Epoch: 34 [30000/50000 (60%)]	Losses default: 0.030073
# Train Epoch: 34 [40000/50000 (80%)]	Losses default: 0.007751
# Train Epoch: 34 [50000/50000 (100%)]	Losses default: 0.084635
# Test set:
# default: Loss: 0.5111	Accuracy: 8925/10000 (89%)
#
# Test set:
# default: Loss: 0.5568	Accuracy: 8863/10000 (89%)
#
# Train Epoch: 35 [0/50000 (0%)]	Losses default: 0.015332
# Train Epoch: 35 [10000/50000 (20%)]	Losses default: 0.061030
# Train Epoch: 35 [20000/50000 (40%)]	Losses default: 0.090041
# Train Epoch: 35 [30000/50000 (60%)]	Losses default: 0.070861
# Train Epoch: 35 [40000/50000 (80%)]	Losses default: 0.024498
# Train Epoch: 35 [50000/50000 (100%)]	Losses default: 0.011809
# Test set:
# default: Loss: 0.5311	Accuracy: 8884/10000 (89%)
#
# Test set:
# default: Loss: 0.5861	Accuracy: 8826/10000 (88%)
#
# Train Epoch: 36 [0/50000 (0%)]	Losses default: 0.088500
# Train Epoch: 36 [10000/50000 (20%)]	Losses default: 0.059123
# Train Epoch: 36 [20000/50000 (40%)]	Losses default: 0.076788
# Train Epoch: 36 [30000/50000 (60%)]	Losses default: 0.024424
# Train Epoch: 36 [40000/50000 (80%)]	Losses default: 0.021523
# Train Epoch: 36 [50000/50000 (100%)]	Losses default: 0.011407
# Test set:
# default: Loss: 0.4976	Accuracy: 8906/10000 (89%)
#
# Test set:
# default: Loss: 0.5593	Accuracy: 8825/10000 (88%)
#
# Train Epoch: 37 [0/50000 (0%)]	Losses default: 0.012064
# Train Epoch: 37 [10000/50000 (20%)]	Losses default: 0.035786
# Train Epoch: 37 [20000/50000 (40%)]	Losses default: 0.037565
# Train Epoch: 37 [30000/50000 (60%)]	Losses default: 0.016948
# Train Epoch: 37 [40000/50000 (80%)]	Losses default: 0.007895
# Train Epoch: 37 [50000/50000 (100%)]	Losses default: 0.064378
# Test set:
# default: Loss: 0.5353	Accuracy: 8882/10000 (89%)
#
# Test set:
# default: Loss: 0.5474	Accuracy: 8860/10000 (89%)
#
# Train Epoch: 38 [0/50000 (0%)]	Losses default: 0.010352
# Train Epoch: 38 [10000/50000 (20%)]	Losses default: 0.019518
# Train Epoch: 38 [20000/50000 (40%)]	Losses default: 0.033993
# Train Epoch: 38 [30000/50000 (60%)]	Losses default: 0.009008
# Train Epoch: 38 [40000/50000 (80%)]	Losses default: 0.010366
# Train Epoch: 38 [50000/50000 (100%)]	Losses default: 0.093746
# Test set:
# default: Loss: 0.5434	Accuracy: 8877/10000 (89%)
#
# Test set:
# default: Loss: 0.5557	Accuracy: 8869/10000 (89%)
#
# Train Epoch: 39 [0/50000 (0%)]	Losses default: 0.063054
# Train Epoch: 39 [10000/50000 (20%)]	Losses default: 0.029232
# Train Epoch: 39 [20000/50000 (40%)]	Losses default: 0.016046
# Train Epoch: 39 [30000/50000 (60%)]	Losses default: 0.008089
# Train Epoch: 39 [40000/50000 (80%)]	Losses default: 0.041706
# Train Epoch: 39 [50000/50000 (100%)]	Losses default: 0.048973
# Test set:
# default: Loss: 0.5553	Accuracy: 8844/10000 (88%)
#
# Test set:
# default: Loss: 0.5938	Accuracy: 8838/10000 (88%)
#
# Train Epoch: 40 [0/50000 (0%)]	Losses default: 0.033870
# Train Epoch: 40 [10000/50000 (20%)]	Losses default: 0.014430
# Train Epoch: 40 [20000/50000 (40%)]	Losses default: 0.068514
# Train Epoch: 40 [30000/50000 (60%)]	Losses default: 0.063674
# Train Epoch: 40 [40000/50000 (80%)]	Losses default: 0.150915
# Train Epoch: 40 [50000/50000 (100%)]	Losses default: 0.031103
# Test set:
# default: Loss: 0.5353	Accuracy: 8898/10000 (89%)
#
# Test set:
# default: Loss: 0.5736	Accuracy: 8877/10000 (89%)
#
# Train Epoch: 41 [0/50000 (0%)]	Losses default: 0.031944
# Train Epoch: 41 [10000/50000 (20%)]	Losses default: 0.044093
# Train Epoch: 41 [20000/50000 (40%)]	Losses default: 0.037513
# Train Epoch: 41 [30000/50000 (60%)]	Losses default: 0.035454
# Train Epoch: 41 [40000/50000 (80%)]	Losses default: 0.176594
# Train Epoch: 41 [50000/50000 (100%)]	Losses default: 0.090211
# Test set:
# default: Loss: 0.5225	Accuracy: 8921/10000 (89%)
#
# Test set:
# default: Loss: 0.6028	Accuracy: 8876/10000 (89%)
#
# Train Epoch: 42 [0/50000 (0%)]	Losses default: 0.039208
# Train Epoch: 42 [10000/50000 (20%)]	Losses default: 0.006601
# Train Epoch: 42 [20000/50000 (40%)]	Losses default: 0.012077
# Train Epoch: 42 [30000/50000 (60%)]	Losses default: 0.222903
# Train Epoch: 42 [40000/50000 (80%)]	Losses default: 0.050127
# Train Epoch: 42 [50000/50000 (100%)]	Losses default: 0.006180
# Test set:
# default: Loss: 0.5369	Accuracy: 8937/10000 (89%)
#
# Test set:
# default: Loss: 0.5620	Accuracy: 8918/10000 (89%)
#
# Train Epoch: 43 [0/50000 (0%)]	Losses default: 0.024890
# Train Epoch: 43 [10000/50000 (20%)]	Losses default: 0.034844
# Train Epoch: 43 [20000/50000 (40%)]	Losses default: 0.003465
# Train Epoch: 43 [30000/50000 (60%)]	Losses default: 0.012013
# Train Epoch: 43 [40000/50000 (80%)]	Losses default: 0.073301
# Train Epoch: 43 [50000/50000 (100%)]	Losses default: 0.021992
# Test set:
# default: Loss: 0.5541	Accuracy: 8910/10000 (89%)
#
# Test set:
# default: Loss: 0.5852	Accuracy: 8874/10000 (89%)
#
# Train Epoch: 44 [0/50000 (0%)]	Losses default: 0.036404
# Train Epoch: 44 [10000/50000 (20%)]	Losses default: 0.015916
# Train Epoch: 44 [20000/50000 (40%)]	Losses default: 0.039124
# Train Epoch: 44 [30000/50000 (60%)]	Losses default: 0.020911
# Train Epoch: 44 [40000/50000 (80%)]	Losses default: 0.032342
# Train Epoch: 44 [50000/50000 (100%)]	Losses default: 0.035604
# Test set:
# default: Loss: 0.5377	Accuracy: 8913/10000 (89%)
#
# Test set:
# default: Loss: 0.5632	Accuracy: 8935/10000 (89%)
#
# Train Epoch: 45 [0/50000 (0%)]	Losses default: 0.045571
# Train Epoch: 45 [10000/50000 (20%)]	Losses default: 0.021427
# Train Epoch: 45 [20000/50000 (40%)]	Losses default: 0.013483
# Train Epoch: 45 [30000/50000 (60%)]	Losses default: 0.102265
# Train Epoch: 45 [40000/50000 (80%)]	Losses default: 0.013738
# Train Epoch: 45 [50000/50000 (100%)]	Losses default: 0.018451
# Test set:
# default: Loss: 0.5185	Accuracy: 8951/10000 (90%)
#
# Test set:
# default: Loss: 0.5749	Accuracy: 8886/10000 (89%)
#
# Train Epoch: 46 [0/50000 (0%)]	Losses default: 0.075036
# Train Epoch: 46 [10000/50000 (20%)]	Losses default: 0.009493
# Train Epoch: 46 [20000/50000 (40%)]	Losses default: 0.108163
# Train Epoch: 46 [30000/50000 (60%)]	Losses default: 0.021309
# Train Epoch: 46 [40000/50000 (80%)]	Losses default: 0.014690
# Train Epoch: 46 [50000/50000 (100%)]	Losses default: 0.055804
# Test set:
# default: Loss: 0.5452	Accuracy: 8928/10000 (89%)
#
# Test set:
# default: Loss: 0.6156	Accuracy: 8867/10000 (89%)
#
# Train Epoch: 47 [0/50000 (0%)]	Losses default: 0.142630
# Train Epoch: 47 [10000/50000 (20%)]	Losses default: 0.124299
# Train Epoch: 47 [20000/50000 (40%)]	Losses default: 0.036818
# Train Epoch: 47 [30000/50000 (60%)]	Losses default: 0.031873
# Train Epoch: 47 [40000/50000 (80%)]	Losses default: 0.016484
# Train Epoch: 47 [50000/50000 (100%)]	Losses default: 0.094045
# Test set:
# default: Loss: 0.5560	Accuracy: 8913/10000 (89%)
#
# Test set:
# default: Loss: 0.6175	Accuracy: 8819/10000 (88%)
#
# Train Epoch: 48 [0/50000 (0%)]	Losses default: 0.020212
# Train Epoch: 48 [10000/50000 (20%)]	Losses default: 0.015105
# Train Epoch: 48 [20000/50000 (40%)]	Losses default: 0.002224
# Train Epoch: 48 [30000/50000 (60%)]	Losses default: 0.062977
# Train Epoch: 48 [40000/50000 (80%)]	Losses default: 0.111287
# Train Epoch: 48 [50000/50000 (100%)]	Losses default: 0.008923
# Test set:
# default: Loss: 0.5740	Accuracy: 8916/10000 (89%)
#
# Test set:
# default: Loss: 0.6444	Accuracy: 8856/10000 (89%)
#
# Train Epoch: 49 [0/50000 (0%)]	Losses default: 0.013539
# Train Epoch: 49 [10000/50000 (20%)]	Losses default: 0.015459
# Train Epoch: 49 [20000/50000 (40%)]	Losses default: 0.012906
# Train Epoch: 49 [30000/50000 (60%)]	Losses default: 0.095248
# Train Epoch: 49 [40000/50000 (80%)]	Losses default: 0.120837
# Train Epoch: 49 [50000/50000 (100%)]	Losses default: 0.105746
# Test set:
# default: Loss: 0.5758	Accuracy: 8901/10000 (89%)
#
# Test set:
# default: Loss: 0.6167	Accuracy: 8843/10000 (88%)
#
# Train Epoch: 50 [0/50000 (0%)]	Losses default: 0.021132
# Train Epoch: 50 [10000/50000 (20%)]	Losses default: 0.025255
# Train Epoch: 50 [20000/50000 (40%)]	Losses default: 0.001254
# Train Epoch: 50 [30000/50000 (60%)]	Losses default: 0.074280
# Train Epoch: 50 [40000/50000 (80%)]	Losses default: 0.105298
# Train Epoch: 50 [50000/50000 (100%)]	Losses default: 0.064689
# Test set:
# default: Loss: 0.5900	Accuracy: 8922/10000 (89%)
#
# Test set:
# default: Loss: 0.6345	Accuracy: 8877/10000 (89%)
#
# Train Epoch: 51 [0/50000 (0%)]	Losses default: 0.055820
# Train Epoch: 51 [10000/50000 (20%)]	Losses default: 0.008685
# Train Epoch: 51 [20000/50000 (40%)]	Losses default: 0.008750
# Train Epoch: 51 [30000/50000 (60%)]	Losses default: 0.036036
# Train Epoch: 51 [40000/50000 (80%)]	Losses default: 0.014178
# Train Epoch: 51 [50000/50000 (100%)]	Losses default: 0.034115
# Test set:
# default: Loss: 0.5562	Accuracy: 8936/10000 (89%)
#
# Test set:
# default: Loss: 0.6192	Accuracy: 8886/10000 (89%)
#
# Train Epoch: 52 [0/50000 (0%)]	Losses default: 0.012903
# Train Epoch: 52 [10000/50000 (20%)]	Losses default: 0.052329
# Train Epoch: 52 [20000/50000 (40%)]	Losses default: 0.014065
# Train Epoch: 52 [30000/50000 (60%)]	Losses default: 0.007076
# Train Epoch: 52 [40000/50000 (80%)]	Losses default: 0.020210
# Train Epoch: 52 [50000/50000 (100%)]	Losses default: 0.022814
# Test set:
# default: Loss: 0.6145	Accuracy: 8895/10000 (89%)
#
# Test set:
# default: Loss: 0.6494	Accuracy: 8845/10000 (88%)
#
# Train Epoch: 53 [0/50000 (0%)]	Losses default: 0.028258
# Train Epoch: 53 [10000/50000 (20%)]	Losses default: 0.003306
# Train Epoch: 53 [20000/50000 (40%)]	Losses default: 0.050131
# Train Epoch: 53 [30000/50000 (60%)]	Losses default: 0.044396
# Train Epoch: 53 [40000/50000 (80%)]	Losses default: 0.023003
# Train Epoch: 53 [50000/50000 (100%)]	Losses default: 0.169531
# Test set:
# default: Loss: 0.6435	Accuracy: 8896/10000 (89%)
#
# Test set:
# default: Loss: 0.7016	Accuracy: 8861/10000 (89%)
#
# Train Epoch: 54 [0/50000 (0%)]	Losses default: 0.002457
# Train Epoch: 54 [10000/50000 (20%)]	Losses default: 0.103384
# Train Epoch: 54 [20000/50000 (40%)]	Losses default: 0.073436
# Train Epoch: 54 [30000/50000 (60%)]	Losses default: 0.007878
# Train Epoch: 54 [40000/50000 (80%)]	Losses default: 0.014130
# Train Epoch: 54 [50000/50000 (100%)]	Losses default: 0.114913
# Test set:
# default: Loss: 0.6088	Accuracy: 8873/10000 (89%)
#
# Test set:
# default: Loss: 0.6761	Accuracy: 8837/10000 (88%)
#
# Train Epoch: 55 [0/50000 (0%)]	Losses default: 0.014785
# Train Epoch: 55 [10000/50000 (20%)]	Losses default: 0.005846
# Train Epoch: 55 [20000/50000 (40%)]	Losses default: 0.033354
# Train Epoch: 55 [30000/50000 (60%)]	Losses default: 0.009870
# Train Epoch: 55 [40000/50000 (80%)]	Losses default: 0.009164
# Train Epoch: 55 [50000/50000 (100%)]	Losses default: 0.023969
# Test set:
# default: Loss: 0.6345	Accuracy: 8894/10000 (89%)
#
# Test set:
# default: Loss: 0.6849	Accuracy: 8858/10000 (89%)
#
# Train Epoch: 56 [0/50000 (0%)]	Losses default: 0.044497
# Train Epoch: 56 [10000/50000 (20%)]	Losses default: 0.053937
# Train Epoch: 56 [20000/50000 (40%)]	Losses default: 0.034296
# Train Epoch: 56 [30000/50000 (60%)]	Losses default: 0.040920
# Train Epoch: 56 [40000/50000 (80%)]	Losses default: 0.039819
# Train Epoch: 56 [50000/50000 (100%)]	Losses default: 0.031638
# Test set:
# default: Loss: 0.6093	Accuracy: 8896/10000 (89%)
#
# Test set:
# default: Loss: 0.6527	Accuracy: 8858/10000 (89%)
#
# Train Epoch: 57 [0/50000 (0%)]	Losses default: 0.002783
# Train Epoch: 57 [10000/50000 (20%)]	Losses default: 0.032730
# Train Epoch: 57 [20000/50000 (40%)]	Losses default: 0.007613
# Train Epoch: 57 [30000/50000 (60%)]	Losses default: 0.003330
# Train Epoch: 57 [40000/50000 (80%)]	Losses default: 0.016324
# Train Epoch: 57 [50000/50000 (100%)]	Losses default: 0.005314
# Test set:
# default: Loss: 0.6325	Accuracy: 8903/10000 (89%)
#
# Test set:
# default: Loss: 0.6875	Accuracy: 8882/10000 (89%)
#
# Train Epoch: 58 [0/50000 (0%)]	Losses default: 0.013558
# Train Epoch: 58 [10000/50000 (20%)]	Losses default: 0.012663
# Train Epoch: 58 [20000/50000 (40%)]	Losses default: 0.003873
# Train Epoch: 58 [30000/50000 (60%)]	Losses default: 0.010106
# Train Epoch: 58 [40000/50000 (80%)]	Losses default: 0.118644
# Train Epoch: 58 [50000/50000 (100%)]	Losses default: 0.014078
# Test set:
# default: Loss: 0.6313	Accuracy: 8955/10000 (90%)
#
# Test set:
# default: Loss: 0.7007	Accuracy: 8888/10000 (89%)
#
# Train Epoch: 59 [0/50000 (0%)]	Losses default: 0.017452
# Train Epoch: 59 [10000/50000 (20%)]	Losses default: 0.009505
# Train Epoch: 59 [20000/50000 (40%)]	Losses default: 0.047754
# Train Epoch: 59 [30000/50000 (60%)]	Losses default: 0.033577
# Train Epoch: 59 [40000/50000 (80%)]	Losses default: 0.002462
# Train Epoch: 59 [50000/50000 (100%)]	Losses default: 0.014112
# Test set:
# default: Loss: 0.6158	Accuracy: 8910/10000 (89%)
#
# Test set:
# default: Loss: 0.6561	Accuracy: 8853/10000 (89%)
#
# Train Epoch: 60 [0/50000 (0%)]	Losses default: 0.007352
# Train Epoch: 60 [10000/50000 (20%)]	Losses default: 0.005090
# Train Epoch: 60 [20000/50000 (40%)]	Losses default: 0.015391
# Train Epoch: 60 [30000/50000 (60%)]	Losses default: 0.010732
# Train Epoch: 60 [40000/50000 (80%)]	Losses default: 0.014248
# Train Epoch: 60 [50000/50000 (100%)]	Losses default: 0.037139
# Test set:
# default: Loss: 0.6221	Accuracy: 8938/10000 (89%)
#
# Test set:
# default: Loss: 0.6396	Accuracy: 8882/10000 (89%)
#
# Train Epoch: 61 [0/50000 (0%)]	Losses default: 0.001748
# Train Epoch: 61 [10000/50000 (20%)]	Losses default: 0.014156
# Train Epoch: 61 [20000/50000 (40%)]	Losses default: 0.018521
# Train Epoch: 61 [30000/50000 (60%)]	Losses default: 0.004572
# Train Epoch: 61 [40000/50000 (80%)]	Losses default: 0.010564
# Train Epoch: 61 [50000/50000 (100%)]	Losses default: 0.022152
# Test set:
# default: Loss: 0.6360	Accuracy: 8914/10000 (89%)
#
# Test set:
# default: Loss: 0.6707	Accuracy: 8865/10000 (89%)
#
# Train Epoch: 62 [0/50000 (0%)]	Losses default: 0.011373
# Train Epoch: 62 [10000/50000 (20%)]	Losses default: 0.165783
# Train Epoch: 62 [20000/50000 (40%)]	Losses default: 0.063485
# Train Epoch: 62 [30000/50000 (60%)]	Losses default: 0.006958
# Train Epoch: 62 [40000/50000 (80%)]	Losses default: 0.089073
# Train Epoch: 62 [50000/50000 (100%)]	Losses default: 0.004075
# Test set:
# default: Loss: 0.6457	Accuracy: 8926/10000 (89%)
#
# Test set:
# default: Loss: 0.6832	Accuracy: 8843/10000 (88%)
#
# Train Epoch: 63 [0/50000 (0%)]	Losses default: 0.073101
# Train Epoch: 63 [10000/50000 (20%)]	Losses default: 0.054529
# Train Epoch: 63 [20000/50000 (40%)]	Losses default: 0.001830
# Train Epoch: 63 [30000/50000 (60%)]	Losses default: 0.223095
# Train Epoch: 63 [40000/50000 (80%)]	Losses default: 0.005660
# Train Epoch: 63 [50000/50000 (100%)]	Losses default: 0.021890
# Test set:
# default: Loss: 0.6288	Accuracy: 8907/10000 (89%)
#
# Test set:
# default: Loss: 0.6680	Accuracy: 8871/10000 (89%)
#
# Train Epoch: 64 [0/50000 (0%)]	Losses default: 0.053184
# Train Epoch: 64 [10000/50000 (20%)]	Losses default: 0.005071
# Train Epoch: 64 [20000/50000 (40%)]	Losses default: 0.015590
# Train Epoch: 64 [30000/50000 (60%)]	Losses default: 0.003795
# Train Epoch: 64 [40000/50000 (80%)]	Losses default: 0.098036
# Train Epoch: 64 [50000/50000 (100%)]	Losses default: 0.268135
# Test set:
# default: Loss: 0.6278	Accuracy: 8909/10000 (89%)
#
# Test set:
# default: Loss: 0.6923	Accuracy: 8887/10000 (89%)
#
# Train Epoch: 65 [0/50000 (0%)]	Losses default: 0.040836
# Train Epoch: 65 [10000/50000 (20%)]	Losses default: 0.030643
# Train Epoch: 65 [20000/50000 (40%)]	Losses default: 0.003975
# Train Epoch: 65 [30000/50000 (60%)]	Losses default: 0.001917
# Train Epoch: 65 [40000/50000 (80%)]	Losses default: 0.049366
# Train Epoch: 65 [50000/50000 (100%)]	Losses default: 0.024789
# Test set:
# default: Loss: 0.7060	Accuracy: 8897/10000 (89%)
#
# Test set:
# default: Loss: 0.7315	Accuracy: 8856/10000 (89%)
#
# Train Epoch: 66 [0/50000 (0%)]	Losses default: 0.002630
# Train Epoch: 66 [10000/50000 (20%)]	Losses default: 0.038538
# Train Epoch: 66 [20000/50000 (40%)]	Losses default: 0.069549
# Train Epoch: 66 [30000/50000 (60%)]	Losses default: 0.037332
# Train Epoch: 66 [40000/50000 (80%)]	Losses default: 0.008606
# Train Epoch: 66 [50000/50000 (100%)]	Losses default: 0.003729
# Test set:
# default: Loss: 0.6792	Accuracy: 8896/10000 (89%)
#
# Test set:
# default: Loss: 0.7113	Accuracy: 8852/10000 (89%)
#
# Train Epoch: 67 [0/50000 (0%)]	Losses default: 0.016195
# Train Epoch: 67 [10000/50000 (20%)]	Losses default: 0.002986
# Train Epoch: 67 [20000/50000 (40%)]	Losses default: 0.014648
# Train Epoch: 67 [30000/50000 (60%)]	Losses default: 0.012181
# Train Epoch: 67 [40000/50000 (80%)]	Losses default: 0.006025
# Train Epoch: 67 [50000/50000 (100%)]	Losses default: 0.024097
# Test set:
# default: Loss: 0.6496	Accuracy: 8910/10000 (89%)
#
# Test set:
# default: Loss: 0.7152	Accuracy: 8829/10000 (88%)
#
# Train Epoch: 68 [0/50000 (0%)]	Losses default: 0.040664
# Train Epoch: 68 [10000/50000 (20%)]	Losses default: 0.038731
# Train Epoch: 68 [20000/50000 (40%)]	Losses default: 0.019944
# Train Epoch: 68 [30000/50000 (60%)]	Losses default: 0.009026
# Train Epoch: 68 [40000/50000 (80%)]	Losses default: 0.025408
# Train Epoch: 68 [50000/50000 (100%)]	Losses default: 0.027487
# Test set:
# default: Loss: 0.6595	Accuracy: 8939/10000 (89%)
#
# Test set:
# default: Loss: 0.6865	Accuracy: 8899/10000 (89%)
#
# Train Epoch: 69 [0/50000 (0%)]	Losses default: 0.001472
# Train Epoch: 69 [10000/50000 (20%)]	Losses default: 0.077359
# Train Epoch: 69 [20000/50000 (40%)]	Losses default: 0.033332
# Train Epoch: 69 [30000/50000 (60%)]	Losses default: 0.006163
# Train Epoch: 69 [40000/50000 (80%)]	Losses default: 0.037878
# Train Epoch: 69 [50000/50000 (100%)]	Losses default: 0.042674
# Test set:
# default: Loss: 0.6435	Accuracy: 8927/10000 (89%)
#
# Test set:
# default: Loss: 0.6945	Accuracy: 8892/10000 (89%)
#
# Train Epoch: 70 [0/50000 (0%)]	Losses default: 0.012038
# Train Epoch: 70 [10000/50000 (20%)]	Losses default: 0.002937
# Train Epoch: 70 [20000/50000 (40%)]	Losses default: 0.022320
# Train Epoch: 70 [30000/50000 (60%)]	Losses default: 0.005429
# Train Epoch: 70 [40000/50000 (80%)]	Losses default: 0.012064
# Train Epoch: 70 [50000/50000 (100%)]	Losses default: 0.003152
# Test set:
# default: Loss: 0.6476	Accuracy: 8933/10000 (89%)
#
# Test set:
# default: Loss: 0.7104	Accuracy: 8868/10000 (89%)
#
# Train Epoch: 71 [0/50000 (0%)]	Losses default: 0.003803
# Train Epoch: 71 [10000/50000 (20%)]	Losses default: 0.001205
# Train Epoch: 71 [20000/50000 (40%)]	Losses default: 0.030741
# Train Epoch: 71 [30000/50000 (60%)]	Losses default: 0.072447
# Train Epoch: 71 [40000/50000 (80%)]	Losses default: 0.010064
# Train Epoch: 71 [50000/50000 (100%)]	Losses default: 0.008628
# Test set:
# default: Loss: 0.6138	Accuracy: 8933/10000 (89%)
#
# Test set:
# default: Loss: 0.6642	Accuracy: 8937/10000 (89%)
#
# Train Epoch: 72 [0/50000 (0%)]	Losses default: 0.004787
# Train Epoch: 72 [10000/50000 (20%)]	Losses default: 0.008602
# Train Epoch: 72 [20000/50000 (40%)]	Losses default: 0.008718
# Train Epoch: 72 [30000/50000 (60%)]	Losses default: 0.003445
# Train Epoch: 72 [40000/50000 (80%)]	Losses default: 0.029529
# Train Epoch: 72 [50000/50000 (100%)]	Losses default: 0.065259
# Test set:
# default: Loss: 0.6747	Accuracy: 8890/10000 (89%)
#
# Test set:
# default: Loss: 0.7280	Accuracy: 8858/10000 (89%)
#
# Train Epoch: 73 [0/50000 (0%)]	Losses default: 0.003493
# Train Epoch: 73 [10000/50000 (20%)]	Losses default: 0.001182
# Train Epoch: 73 [20000/50000 (40%)]	Losses default: 0.001778
# Train Epoch: 73 [30000/50000 (60%)]	Losses default: 0.006521
# Train Epoch: 73 [40000/50000 (80%)]	Losses default: 0.017803
# Train Epoch: 73 [50000/50000 (100%)]	Losses default: 0.021106
# Test set:
# default: Loss: 0.6398	Accuracy: 8916/10000 (89%)
#
# Test set:
# default: Loss: 0.6878	Accuracy: 8909/10000 (89%)
#
# Train Epoch: 74 [0/50000 (0%)]	Losses default: 0.006990
# Train Epoch: 74 [10000/50000 (20%)]	Losses default: 0.000905
# Train Epoch: 74 [20000/50000 (40%)]	Losses default: 0.080188
# Train Epoch: 74 [30000/50000 (60%)]	Losses default: 0.031169
# Train Epoch: 74 [40000/50000 (80%)]	Losses default: 0.013289
# Train Epoch: 74 [50000/50000 (100%)]	Losses default: 0.050402
# Test set:
# default: Loss: 0.6550	Accuracy: 8959/10000 (90%)
#
# Test set:
# default: Loss: 0.6999	Accuracy: 8913/10000 (89%)
#
# Train Epoch: 75 [0/50000 (0%)]	Losses default: 0.017803
# Train Epoch: 75 [10000/50000 (20%)]	Losses default: 0.000475
# Train Epoch: 75 [20000/50000 (40%)]	Losses default: 0.004333
# Train Epoch: 75 [30000/50000 (60%)]	Losses default: 0.039326
# Train Epoch: 75 [40000/50000 (80%)]	Losses default: 0.003495
# Train Epoch: 75 [50000/50000 (100%)]	Losses default: 0.007843
# Test set:
# default: Loss: 0.6397	Accuracy: 8943/10000 (89%)
#
# Test set:
# default: Loss: 0.7006	Accuracy: 8904/10000 (89%)
#
# Train Epoch: 76 [0/50000 (0%)]	Losses default: 0.005847
# Train Epoch: 76 [10000/50000 (20%)]	Losses default: 0.012751
# Train Epoch: 76 [20000/50000 (40%)]	Losses default: 0.011045
# Train Epoch: 76 [30000/50000 (60%)]	Losses default: 0.013804
# Train Epoch: 76 [40000/50000 (80%)]	Losses default: 0.036004
# Train Epoch: 76 [50000/50000 (100%)]	Losses default: 0.019298
# Test set:
# default: Loss: 0.7038	Accuracy: 8919/10000 (89%)
#
# Test set:
# default: Loss: 0.7663	Accuracy: 8868/10000 (89%)
#
# Train Epoch: 77 [0/50000 (0%)]	Losses default: 0.001501
# Train Epoch: 77 [10000/50000 (20%)]	Losses default: 0.006467
# Train Epoch: 77 [20000/50000 (40%)]	Losses default: 0.040625
# Train Epoch: 77 [30000/50000 (60%)]	Losses default: 0.137136
# Train Epoch: 77 [40000/50000 (80%)]	Losses default: 0.024766
# Train Epoch: 77 [50000/50000 (100%)]	Losses default: 0.019195
# Test set:
# default: Loss: 0.6390	Accuracy: 8937/10000 (89%)
#
# Test set:
# default: Loss: 0.6883	Accuracy: 8886/10000 (89%)
#
# Train Epoch: 78 [0/50000 (0%)]	Losses default: 0.006074
# Train Epoch: 78 [10000/50000 (20%)]	Losses default: 0.025662
# Train Epoch: 78 [20000/50000 (40%)]	Losses default: 0.004322
# Train Epoch: 78 [30000/50000 (60%)]	Losses default: 0.012337
# Train Epoch: 78 [40000/50000 (80%)]	Losses default: 0.023038
# Train Epoch: 78 [50000/50000 (100%)]	Losses default: 0.001476
# Test set:
# default: Loss: 0.7058	Accuracy: 8890/10000 (89%)
#
# Test set:
# default: Loss: 0.7383	Accuracy: 8839/10000 (88%)
#
# Train Epoch: 79 [0/50000 (0%)]	Losses default: 0.006079
# Train Epoch: 79 [10000/50000 (20%)]	Losses default: 0.212863
# Train Epoch: 79 [20000/50000 (40%)]	Losses default: 0.008676
# Train Epoch: 79 [30000/50000 (60%)]	Losses default: 0.010343
# Train Epoch: 79 [40000/50000 (80%)]	Losses default: 0.002317
# Train Epoch: 79 [50000/50000 (100%)]	Losses default: 0.063490
# Test set:
# default: Loss: 0.6776	Accuracy: 8915/10000 (89%)
#
# Test set:
# default: Loss: 0.7129	Accuracy: 8894/10000 (89%)
#
# Train Epoch: 80 [0/50000 (0%)]	Losses default: 0.002410
# Train Epoch: 80 [10000/50000 (20%)]	Losses default: 0.021638
# Train Epoch: 80 [20000/50000 (40%)]	Losses default: 0.003057
# Train Epoch: 80 [30000/50000 (60%)]	Losses default: 0.068049
# Train Epoch: 80 [40000/50000 (80%)]	Losses default: 0.002389
# Train Epoch: 80 [50000/50000 (100%)]	Losses default: 0.006532
# Test set:
# default: Loss: 0.7238	Accuracy: 8850/10000 (88%)
#
# Test set:
# default: Loss: 0.7571	Accuracy: 8821/10000 (88%)
#
# Train Epoch: 81 [0/50000 (0%)]	Losses default: 0.011227
# Train Epoch: 81 [10000/50000 (20%)]	Losses default: 0.000190
# Train Epoch: 81 [20000/50000 (40%)]	Losses default: 0.011652
# Train Epoch: 81 [30000/50000 (60%)]	Losses default: 0.000848
# Train Epoch: 81 [40000/50000 (80%)]	Losses default: 0.006336
# Train Epoch: 81 [50000/50000 (100%)]	Losses default: 0.001724
# Test set:
# default: Loss: 0.6589	Accuracy: 8911/10000 (89%)
#
# Test set:
# default: Loss: 0.6780	Accuracy: 8925/10000 (89%)
#
# Train Epoch: 82 [0/50000 (0%)]	Losses default: 0.002138
# Train Epoch: 82 [10000/50000 (20%)]	Losses default: 0.011234
# Train Epoch: 82 [20000/50000 (40%)]	Losses default: 0.002211
# Train Epoch: 82 [30000/50000 (60%)]	Losses default: 0.001239
# Train Epoch: 82 [40000/50000 (80%)]	Losses default: 0.007973
# Train Epoch: 82 [50000/50000 (100%)]	Losses default: 0.001827
# Test set:
# default: Loss: 0.6823	Accuracy: 8909/10000 (89%)
#
# Test set:
# default: Loss: 0.7305	Accuracy: 8878/10000 (89%)
#
# Train Epoch: 83 [0/50000 (0%)]	Losses default: 0.012642
# Train Epoch: 83 [10000/50000 (20%)]	Losses default: 0.005267
# Train Epoch: 83 [20000/50000 (40%)]	Losses default: 0.003053
# Train Epoch: 83 [30000/50000 (60%)]	Losses default: 0.008093
# Train Epoch: 83 [40000/50000 (80%)]	Losses default: 0.022545
# Train Epoch: 83 [50000/50000 (100%)]	Losses default: 0.006308
# Test set:
# default: Loss: 0.6627	Accuracy: 8874/10000 (89%)
#
# Test set:
# default: Loss: 0.7085	Accuracy: 8872/10000 (89%)
#
# Train Epoch: 84 [0/50000 (0%)]	Losses default: 0.006229
# Train Epoch: 84 [10000/50000 (20%)]	Losses default: 0.007438
# Train Epoch: 84 [20000/50000 (40%)]	Losses default: 0.003935
# Train Epoch: 84 [30000/50000 (60%)]	Losses default: 0.016889
# Train Epoch: 84 [40000/50000 (80%)]	Losses default: 0.007587
# Train Epoch: 84 [50000/50000 (100%)]	Losses default: 0.023318
# Test set:
# default: Loss: 0.6921	Accuracy: 8924/10000 (89%)
#
# Test set:
# default: Loss: 0.7316	Accuracy: 8910/10000 (89%)
#
# Train Epoch: 85 [0/50000 (0%)]	Losses default: 0.015903
# Train Epoch: 85 [10000/50000 (20%)]	Losses default: 0.001815
# Train Epoch: 85 [20000/50000 (40%)]	Losses default: 0.000604
# Train Epoch: 85 [30000/50000 (60%)]	Losses default: 0.004404
# Train Epoch: 85 [40000/50000 (80%)]	Losses default: 0.014992
# Train Epoch: 85 [50000/50000 (100%)]	Losses default: 0.016108
# Test set:
# default: Loss: 0.6468	Accuracy: 8945/10000 (89%)
#
# Test set:
# default: Loss: 0.7181	Accuracy: 8929/10000 (89%)
#
# Train Epoch: 86 [0/50000 (0%)]	Losses default: 0.005912
# Train Epoch: 86 [10000/50000 (20%)]	Losses default: 0.001651
# Train Epoch: 86 [20000/50000 (40%)]	Losses default: 0.006579
# Train Epoch: 86 [30000/50000 (60%)]	Losses default: 0.089206
# Train Epoch: 86 [40000/50000 (80%)]	Losses default: 0.002290
# Train Epoch: 86 [50000/50000 (100%)]	Losses default: 0.017922
# Test set:
# default: Loss: 0.6569	Accuracy: 8942/10000 (89%)
#
# Test set:
# default: Loss: 0.7391	Accuracy: 8932/10000 (89%)
#
# Train Epoch: 87 [0/50000 (0%)]	Losses default: 0.002740
# Train Epoch: 87 [10000/50000 (20%)]	Losses default: 0.013679
# Train Epoch: 87 [20000/50000 (40%)]	Losses default: 0.019768
# Train Epoch: 87 [30000/50000 (60%)]	Losses default: 0.002773
# Train Epoch: 87 [40000/50000 (80%)]	Losses default: 0.042296
# Train Epoch: 87 [50000/50000 (100%)]	Losses default: 0.024412
# Test set:
# default: Loss: 0.6995	Accuracy: 8912/10000 (89%)
#
# Test set:
# default: Loss: 0.7697	Accuracy: 8912/10000 (89%)
#
# Train Epoch: 88 [0/50000 (0%)]	Losses default: 0.002394
# Train Epoch: 88 [10000/50000 (20%)]	Losses default: 0.025847
# Train Epoch: 88 [20000/50000 (40%)]	Losses default: 0.005662
# Train Epoch: 88 [30000/50000 (60%)]	Losses default: 0.005013
# Train Epoch: 88 [40000/50000 (80%)]	Losses default: 0.016876
# Train Epoch: 88 [50000/50000 (100%)]	Losses default: 0.009149
# Test set:
# default: Loss: 0.6472	Accuracy: 8972/10000 (90%)
#
# Test set:
# default: Loss: 0.7149	Accuracy: 8900/10000 (89%)
#
# Train Epoch: 89 [0/50000 (0%)]	Losses default: 0.045131
# Train Epoch: 89 [10000/50000 (20%)]	Losses default: 0.000517
# Train Epoch: 89 [20000/50000 (40%)]	Losses default: 0.012177
# Train Epoch: 89 [30000/50000 (60%)]	Losses default: 0.002544
# Train Epoch: 89 [40000/50000 (80%)]	Losses default: 0.002804
# Train Epoch: 89 [50000/50000 (100%)]	Losses default: 0.006530
# Test set:
# default: Loss: 0.6661	Accuracy: 8961/10000 (90%)
#
# Test set:
# default: Loss: 0.7445	Accuracy: 8921/10000 (89%)
#
# Train Epoch: 90 [0/50000 (0%)]	Losses default: 0.039340
# Train Epoch: 90 [10000/50000 (20%)]	Losses default: 0.075606
# Train Epoch: 90 [20000/50000 (40%)]	Losses default: 0.005267
# Train Epoch: 90 [30000/50000 (60%)]	Losses default: 0.009325
# Train Epoch: 90 [40000/50000 (80%)]	Losses default: 0.001071
# Train Epoch: 90 [50000/50000 (100%)]	Losses default: 0.000226
# Test set:
# default: Loss: 0.7163	Accuracy: 8944/10000 (89%)
#
# Test set:
# default: Loss: 0.7743	Accuracy: 8890/10000 (89%)
#
# Train Epoch: 91 [0/50000 (0%)]	Losses default: 0.006170
# Train Epoch: 91 [10000/50000 (20%)]	Losses default: 0.000811
# Train Epoch: 91 [20000/50000 (40%)]	Losses default: 0.092893
# Train Epoch: 91 [30000/50000 (60%)]	Losses default: 0.003171
# Train Epoch: 91 [40000/50000 (80%)]	Losses default: 0.024924
# Train Epoch: 91 [50000/50000 (100%)]	Losses default: 0.001824
# Test set:
# default: Loss: 0.6671	Accuracy: 8906/10000 (89%)
#
# Test set:
# default: Loss: 0.7256	Accuracy: 8933/10000 (89%)
#
# Train Epoch: 92 [0/50000 (0%)]	Losses default: 0.002519
# Train Epoch: 92 [10000/50000 (20%)]	Losses default: 0.007493
# Train Epoch: 92 [20000/50000 (40%)]	Losses default: 0.006483
# Train Epoch: 92 [30000/50000 (60%)]	Losses default: 0.005007
# Train Epoch: 92 [40000/50000 (80%)]	Losses default: 0.004807
# Train Epoch: 92 [50000/50000 (100%)]	Losses default: 0.009729
# Test set:
# default: Loss: 0.7111	Accuracy: 8887/10000 (89%)
#
# Test set:
# default: Loss: 0.7786	Accuracy: 8877/10000 (89%)
#
# Train Epoch: 93 [0/50000 (0%)]	Losses default: 0.003659
# Train Epoch: 93 [10000/50000 (20%)]	Losses default: 0.002411
# Train Epoch: 93 [20000/50000 (40%)]	Losses default: 0.000168
# Train Epoch: 93 [30000/50000 (60%)]	Losses default: 0.000620
# Train Epoch: 93 [40000/50000 (80%)]	Losses default: 0.085363
# Train Epoch: 93 [50000/50000 (100%)]	Losses default: 0.032538
# Test set:
# default: Loss: 0.6986	Accuracy: 8928/10000 (89%)
#
# Test set:
# default: Loss: 0.7453	Accuracy: 8924/10000 (89%)
#
# Train Epoch: 94 [0/50000 (0%)]	Losses default: 0.037142
# Train Epoch: 94 [10000/50000 (20%)]	Losses default: 0.031937
# Train Epoch: 94 [20000/50000 (40%)]	Losses default: 0.046316
# Train Epoch: 94 [30000/50000 (60%)]	Losses default: 0.008830
# Train Epoch: 94 [40000/50000 (80%)]	Losses default: 0.000910
# Train Epoch: 94 [50000/50000 (100%)]	Losses default: 0.002957
# Test set:
# default: Loss: 0.7257	Accuracy: 8882/10000 (89%)
#
# Test set:
# default: Loss: 0.7762	Accuracy: 8870/10000 (89%)
#
# Train Epoch: 95 [0/50000 (0%)]	Losses default: 0.006607
# Train Epoch: 95 [10000/50000 (20%)]	Losses default: 0.010425
# Train Epoch: 95 [20000/50000 (40%)]	Losses default: 0.001898
# Train Epoch: 95 [30000/50000 (60%)]	Losses default: 0.000862
# Train Epoch: 95 [40000/50000 (80%)]	Losses default: 0.037786
# Train Epoch: 95 [50000/50000 (100%)]	Losses default: 0.004362
# Test set:
# default: Loss: 0.7030	Accuracy: 8959/10000 (90%)
#
# Test set:
# default: Loss: 0.7385	Accuracy: 8934/10000 (89%)
#
# Train Epoch: 96 [0/50000 (0%)]	Losses default: 0.000411
# Train Epoch: 96 [10000/50000 (20%)]	Losses default: 0.001102
# Train Epoch: 96 [20000/50000 (40%)]	Losses default: 0.011092
# Train Epoch: 96 [30000/50000 (60%)]	Losses default: 0.040889
# Train Epoch: 96 [40000/50000 (80%)]	Losses default: 0.002181
# Train Epoch: 96 [50000/50000 (100%)]	Losses default: 0.001302
# Test set:
# default: Loss: 0.7109	Accuracy: 8949/10000 (89%)
#
# Test set:
# default: Loss: 0.7886	Accuracy: 8881/10000 (89%)
#
# Train Epoch: 97 [0/50000 (0%)]	Losses default: 0.016008
# Train Epoch: 97 [10000/50000 (20%)]	Losses default: 0.038727
# Train Epoch: 97 [20000/50000 (40%)]	Losses default: 0.044818
# Train Epoch: 97 [30000/50000 (60%)]	Losses default: 0.003101
# Train Epoch: 97 [40000/50000 (80%)]	Losses default: 0.046734
# Train Epoch: 97 [50000/50000 (100%)]	Losses default: 0.004984
# Test set:
# default: Loss: 0.7278	Accuracy: 8943/10000 (89%)
#
# Test set:
# default: Loss: 0.7542	Accuracy: 8942/10000 (89%)
#
# Train Epoch: 98 [0/50000 (0%)]	Losses default: 0.005947
# Train Epoch: 98 [10000/50000 (20%)]	Losses default: 0.000727
# Train Epoch: 98 [20000/50000 (40%)]	Losses default: 0.033877
# Train Epoch: 98 [30000/50000 (60%)]	Losses default: 0.001307
# Train Epoch: 98 [40000/50000 (80%)]	Losses default: 0.010292
# Train Epoch: 98 [50000/50000 (100%)]	Losses default: 0.063773
# Test set:
# default: Loss: 0.7166	Accuracy: 8900/10000 (89%)
#
# Test set:
# default: Loss: 0.7434	Accuracy: 8898/10000 (89%)
#
# Train Epoch: 99 [0/50000 (0%)]	Losses default: 0.004767
# Train Epoch: 99 [10000/50000 (20%)]	Losses default: 0.144470
# Train Epoch: 99 [20000/50000 (40%)]	Losses default: 0.003747
# Train Epoch: 99 [30000/50000 (60%)]	Losses default: 0.029092
# Train Epoch: 99 [40000/50000 (80%)]	Losses default: 0.007539
# Train Epoch: 99 [50000/50000 (100%)]	Losses default: 0.002822
# Test set:
# default: Loss: 0.7427	Accuracy: 8962/10000 (90%)
#
# Test set:
# default: Loss: 0.8083	Accuracy: 8886/10000 (89%)
#
# Train Epoch: 100 [0/50000 (0%)]	Losses default: 0.008554
# Train Epoch: 100 [10000/50000 (20%)]	Losses default: 0.005665
# Train Epoch: 100 [20000/50000 (40%)]	Losses default: 0.010347
# Train Epoch: 100 [30000/50000 (60%)]	Losses default: 0.002427
# Train Epoch: 100 [40000/50000 (80%)]	Losses default: 0.011110
# Train Epoch: 100 [50000/50000 (100%)]	Losses default: 0.009916
# Test set:
# default: Loss: 0.7186	Accuracy: 8906/10000 (89%)
#
# Test set:
# default: Loss: 0.8052	Accuracy: 8860/10000 (89%)
